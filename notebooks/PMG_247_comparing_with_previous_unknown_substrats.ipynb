# %% [markdown]
# ### Imports

# %%
import sys
mypath = "/home/basia/Documents/spectroscopy/magnetstein"
sys.path.insert(0, mypath)

# %%
import numpy as np
import pandas as pd
import os
from masserstein import NMRSpectrum, estimate_proportions
import matplotlib.pyplot as plt
import pulp
import pickle

# %% [markdown]
# ### Data

# %%
experiment_name = 'PMG 247 monitoring'

# %%
experiment_names = ['Sacharose hydrolysis',
                   'Silane',
                   'PMG 247 monitoring']

# %%
mixture_paths = {'Sacharose hydrolysis': '../data/sacharose_1000/all.csv',
                'Silane': '../data/silan/pmg166_3rdseries_full.csv',
                'PMG 247 monitoring': '../data/PMG_247/PMG247_monitoring_pierwsze_54_widma.csv'
                }

mixture_separators = {'Sacharose hydrolysis': '\t',
                'Silane': '\t',
                'PMG 247 monitoring': ','
                }

results_paths = {'Sacharose hydrolysis': '../results/sacharose_1000/comparing_with_previous/unknown_substrats/',
                'Silane': '../results/silan/comparing_with_previous/unknown_substrats/',
                'PMG 247 monitoring': '../results/PMG_247/comparing_with_previous/unknown_substrats/'
                }

# %% [markdown]
# #### Mixture in time

# %%
mixture_time_data = pd.read_csv(mixture_paths[experiment_name], sep = mixture_separators[experiment_name])
#data = pd.read_csv('../data/sacharose_1000/all.csv', sep = '\t').iloc[:,:-1]

# %%
names = ['ppm'] + ['t' + str(nb) for nb in range(1, mixture_time_data.shape[1])]

# %%
mixture_time_data.columns = names

# %%
def load_spectrum(mixture_time_data, moment_of_time):
    ppm = mixture_time_data['ppm']
    intensity = mixture_time_data['t'+str(moment_of_time)]
    sp = NMRSpectrum(confs = list(zip(ppm, intensity)))
    return sp

# %%
sp1 = load_spectrum(mixture_time_data, 1)
sp_last = load_spectrum(mixture_time_data, mixture_time_data.shape[1]-1)

# %%
plt.gca().invert_xaxis()
NMRSpectrum.plot_all([sp1, sp_last], profile=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Estimation

# %%
kappa = 0.1
kappa_th = 0.1

# %%
proportions_in_times = []
noise_proportions_in_times = []

sp1 = load_spectrum(mixture_time_data, 1)
sp1.trim_negative_intensities()
sp1.normalize()

for i in range(2, mixture_time_data.shape[1]):
    print('This is timepoint '+str(i)+'.\n')
    current = load_spectrum(mixture_time_data, i)
    previous = load_spectrum(mixture_time_data, i-1)
    estimation = estimate_proportions(current, [previous], what_to_compare='area',
                                      solver=pulp.GUROBI(msg=False),
                                     MTD=kappa, MTD_th=kappa_th)

    proportions_in_times.append(estimation['proportions'])
    noise_proportions_in_times.append(estimation['proportion_of_noise_in_components'])
    
    print('Proportions:\n')
    print(estimation['proportions'])
    print('\n')
    print('Proportion_of_noise_in_components:\n')
    print(estimation['proportion_of_noise_in_components'])
    print('\n')
# Out:
# This is timepoint 2.
#
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-13
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# /home/basia/.local/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Proportions:
#
# [0.9939026511380005]
#
#
# Proportion_of_noise_in_components:
#
# 0.007420098393000003
#
#
# This is timepoint 3.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.996635980945004]
#
#
# Proportion_of_noise_in_components:
#
# 0.005149312176000021
#
#
# This is timepoint 4.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9973392934989973]
#
#
# Proportion_of_noise_in_components:
#
# 0.005072248452999986
#
#
# This is timepoint 5.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9961040005199979]
#
#
# Proportion_of_noise_in_components:
#
# 0.004793636522999989
#
#
# This is timepoint 6.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.996145433750002]
#
#
# Proportion_of_noise_in_components:
#
# 0.00495311233400001
#
#
# This is timepoint 7.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9974454131320013]
#
#
# Proportion_of_noise_in_components:
#
# 0.006353733146000008
#
#
# This is timepoint 8.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.998371490767002]
#
#
# Proportion_of_noise_in_components:
#
# 0.007049578381000014
#
#
# This is timepoint 9.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9968792792159985]
#
#
# Proportion_of_noise_in_components:
#
# 0.006439648086999991
#
#
# This is timepoint 10.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9982457707959992]
#
#
# Proportion_of_noise_in_components:
#
# 0.008036004765999994
#
#
# This is timepoint 11.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9977937873029973]
#
#
# Proportion_of_noise_in_components:
#
# 0.009605344454999973
#
#
# This is timepoint 12.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.996114525743]
#
#
# Proportion_of_noise_in_components:
#
# 0.012289665412
#
#
# This is timepoint 13.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9905823794029984]
#
#
# Proportion_of_noise_in_components:
#
# 0.018039707149999973
#
#
# This is timepoint 14.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9869889780530007]
#
#
# Proportion_of_noise_in_components:
#
# 0.01542095553500001
#
#
# This is timepoint 15.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9909062903869954]
#
#
# Proportion_of_noise_in_components:
#
# 0.009648373867999957
#
#
# This is timepoint 16.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9938309462759974]
#
#
# Proportion_of_noise_in_components:
#
# 0.009999030465999974
#
#
# This is timepoint 17.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9939494160610008]
#
#
# Proportion_of_noise_in_components:
#
# 0.008735997663000006
#
#
# This is timepoint 18.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9949860331309988]
#
#
# Proportion_of_noise_in_components:
#
# 0.007400814025999992
#
#
# This is timepoint 19.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9954917147090027]
#
#
# Proportion_of_noise_in_components:
#
# 0.006499874062000017
#
#
# This is timepoint 20.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9954736372049988]
#
#
# Proportion_of_noise_in_components:
#
# 0.005303585848999994
#
#
# This is timepoint 21.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9957361878859987]
#
#
# Proportion_of_noise_in_components:
#
# 0.005255725888999993
#
#
# This is timepoint 22.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9957246613329986]
#
#
# Proportion_of_noise_in_components:
#
# 0.005027717923999993
#
#
# This is timepoint 23.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9962591391289999]
#
#
# Proportion_of_noise_in_components:
#
# 0.005115597199999999
#
#
# This is timepoint 24.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9963403501369967]
#
#
# Proportion_of_noise_in_components:
#
# 0.004984644376999983
#
#
# This is timepoint 25.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9967019902490013]
#
#
# Proportion_of_noise_in_components:
#
# 0.004635073075000006
#
#
# This is timepoint 26.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9971021703460016]
#
#
# Proportion_of_noise_in_components:
#
# 0.004330449757000007
#
#
# This is timepoint 27.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9970928624280018]
#
#
# Proportion_of_noise_in_components:
#
# 0.004475561022000008
#
#
# This is timepoint 28.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9970283236140011]
#
#
# Proportion_of_noise_in_components:
#
# 0.003983145474000005
#
#
# This is timepoint 29.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.997794781284002]
#
#
# Proportion_of_noise_in_components:
#
# 0.0037204126130000073
#
#
# This is timepoint 30.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9981040602849965]
#
#
# Proportion_of_noise_in_components:
#
# 0.0032615537599999887
#
#
# This is timepoint 31.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9983757048019978]
#
#
# Proportion_of_noise_in_components:
#
# 0.002748427249999994
#
#
# This is timepoint 32.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9993897835869974]
#
#
# Proportion_of_noise_in_components:
#
# 0.0028113571949999927
#
#
# This is timepoint 33.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9993593695290004]
#
#
# Proportion_of_noise_in_components:
#
# 0.0020940630710000008
#
#
# This is timepoint 34.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9993926750159992]
#
#
# Proportion_of_noise_in_components:
#
# 0.0018163228879999984
#
#
# This is timepoint 35.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9996308893059993]
#
#
# Proportion_of_noise_in_components:
#
# 0.0014707298509999988
#
#
# This is timepoint 36.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9993243977290011]
#
#
# Proportion_of_noise_in_components:
#
# 0.0011011000260000012
#
#
# This is timepoint 37.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9996401989119987]
#
#
# Proportion_of_noise_in_components:
#
# 0.0009676637849999988
#
#
# This is timepoint 38.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999180900190009]
#
#
# Proportion_of_noise_in_components:
#
# 0.001157519582000001
#
#
# This is timepoint 39.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9997340033880018]
#
#
# Proportion_of_noise_in_components:
#
# 0.0008739476150000015
#
#
# This is timepoint 40.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9994970377860022]
#
#
# Proportion_of_noise_in_components:
#
# 0.0006522622740000014
#
#
# This is timepoint 41.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9998542278799964]
#
#
# Proportion_of_noise_in_components:
#
# 0.0008112427749999971
#
#
# This is timepoint 42.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9997124147770005]
#
#
# Proportion_of_noise_in_components:
#
# 0.0006974261990000003
#
#
# This is timepoint 43.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9996400251860014]
#
#
# Proportion_of_noise_in_components:
#
# 0.0005083965730000007
#
#
# This is timepoint 44.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9995831189030022]
#
#
# Proportion_of_noise_in_components:
#
# 0.0004020562760000009
#
#
# This is timepoint 45.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999011206459978]
#
#
# Proportion_of_noise_in_components:
#
# 0.0007273450319999984
#
#
# This is timepoint 46.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9998226384020036]
#
#
# Proportion_of_noise_in_components:
#
# 0.0003360739620000012
#
#
# This is timepoint 47.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.999685418876999]
#
#
# Proportion_of_noise_in_components:
#
# 0.00011079568599999989
#
#
# This is timepoint 48.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999364184369997]
#
#
# Proportion_of_noise_in_components:
#
# 0.0002676676819999999
#
#
# This is timepoint 49.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999495524530029]
#
#
# Proportion_of_noise_in_components:
#
# 0.00026927415100000076
#
#
# This is timepoint 50.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9997387146679982]
#
#
# Proportion_of_noise_in_components:
#
# 1.690075499999997e-05
#
#
# This is timepoint 51.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999753983740004]
#
#
# Proportion_of_noise_in_components:
#
# 0.00023692445500000012
#
#
# This is timepoint 52.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999710883129995]
#
#
# Proportion_of_noise_in_components:
#
# 7.839872699999996e-05
#
#
# This is timepoint 53.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.999889647969]
#
#
# Proportion_of_noise_in_components:
#
# 0.000118857793
#
#
# This is timepoint 54.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Component's spectrum 0 cannot contain negative intensities.
# Setting negative intensities to zero.
# Component's spectrum 0 is not normalized
# Normalizing component's spectrum 0.
# Proportions:
#
# [0.9999025600709993]
#
#
# Proportion_of_noise_in_components:
#
# 4.5705530999999976e-05

# %%
len(proportions_in_times)
# Out:
# 53

# %%
max([prop[0] for prop in proportions_in_times])
# Out:
# 0.9999753983740004

# %%
min([prop[0] for prop in proportions_in_times])
# Out:
# 0.9869889780530007

# %%
rel_proportions = [1]
for i, prop in enumerate(proportions_in_times):
    rel_proportions.append(rel_proportions[-1]*prop[0])

# %%
plt.plot(range(1+len(proportions_in_times)), rel_proportions, 'p')

# %%
prop = [prop[0] for prop in proportions_in_times]

# %%
with open(results_paths[experiment_name]+'proportions_in_times_'+str(kappa)+'_'+str(kappa_th)+'.pkl', 'wb') as f:
    pickle.dump(prop, f)

# %%
with open(results_paths[experiment_name]+'noise_proportions_in_times_'+str(kappa)+'_'+str(kappa_th)+'.pkl', 'wb') as f:
    pickle.dump(noise_proportions_in_times, f)

# %% [markdown]
# ### Reading the results

# %%
with open(results_paths[experiment_name]+'proportions_in_times_'+str(kappa)+'_'+str(kappa_th)+'.pkl', 'rb') as f:
    y = pickle.load(f)
    y = np.array(y).reshape(-1,1)
