# %% [markdown]
# ### Imports

# %%
import sys
mypath = "/home/basia/Documents/spectroscopy/magnetstein"
sys.path.insert(0, mypath)

# %%
import numpy as np
import pandas as pd
import os
from masserstein import NMRSpectrum, estimate_proportions
import matplotlib.pyplot as plt
import pulp
import pickle

# %% [markdown]
# ### Data

# %%
experiment_name = 'PMG 247 monitoring'

# %%
experiment_names = ['Sacharose hydrolysis',
                   'Silane',
                   'PMG 247 monitoring']

# %%
mixture_paths = {'Sacharose hydrolysis': '../data/sacharose_1000/all.csv',
                'Silane': '../data/silan/pmg166_3rdseries_full.csv',
                'PMG 247 monitoring': '../data/PMG_247/PMG247_monitoring_pierwsze_54_widma.csv'
                }

reagents_paths = {'Sacharose hydrolysis': ['../data/sacharose_1000/sucrose.csv', 
                                            '../data/sacharose_1000/glucose.csv',
                                            '../data/sacharose_1000/fructose.csv'],
                'Silane': [],
                'PMG 247 monitoring': ['../data/PMG_247/PMG247_widmo0.csv']
                }

mixture_separators = {'Sacharose hydrolysis': '\t',
                'Silane': '\t',
                'PMG 247 monitoring': ','
                }

reagents_separators = {'Sacharose hydrolysis': '\t',
                'Silane': '\t',
                'PMG 247 monitoring': '\t'
                }

# %% [markdown]
# #### Mixture in time

# %%
mixture_time_data = pd.read_csv(mixture_paths[experiment_name], sep = mixture_separators[experiment_name])
#data = pd.read_csv('../data/sacharose_1000/all.csv', sep = '\t').iloc[:,:-1]

# %%
names = ['ppm'] + ['t' + str(nb) for nb in range(1, mixture_time_data.shape[1])]

# %%
mixture_time_data.columns = names

# %%
def load_spectrum(mixture_time_data, moment_of_time):
    ppm = mixture_time_data['ppm']
    intensity = mixture_time_data['t'+str(moment_of_time)]
    sp = NMRSpectrum(confs = list(zip(ppm, intensity)))
    return sp

# %% [markdown]
# #### Reagents

# %%
reagents_spectra = []
for reagent in reagents_paths[experiment_name]:
    reag = pd.read_csv(reagent, sep=reagents_separators[experiment_name], header=None).iloc[:,:2]
    reagents_spectra.append(reag)

# %%
reagents_spectra2 = []
for reag in reagents_spectra:
    ppm = reag.iloc[:,0]
    ints = reag.iloc[:,1]
    sp = NMRSpectrum(confs = list(zip(ppm, ints)))
    sp.trim_negative_intensities()
    sp.normalize()
    reagents_spectra2.append(sp)
reagents_spectra = reagents_spectra2
del(reagents_spectra2)

# %%
NMRSpectrum.plot_all(reagents_spectra, profile=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Estimation

# %%
kappa = 1
kappa_th = 1

# %%
proportions_in_times = []
noise_proportions_in_times = []

sp1 = load_spectrum(mixture_time_data, 1)
sp1.trim_negative_intensities()
sp1.normalize()

for i in range(1, mixture_time_data.shape[1]):
    print('This is timepoint '+str(i)+'.\n')
    mix = load_spectrum(mixture_time_data, i)
    estimation = estimate_proportions(mix, reagents_spectra, what_to_compare='area', 
                                      solver=pulp.GUROBI(msg=False),
                                     MTD=kappa, MTD_th=kappa_th)
        
    proportions_in_times.append(estimation['proportions'])
    noise_proportions_in_times.append(estimation['proportion_of_noise_in_components'])
    
    print('Proportions:\n')
    print(estimation['proportions'])
    print('\n')
    print('Proportion_of_noise_in_components:\n')
    print(estimation['proportion_of_noise_in_components'])
    print('\n')
# Out:
# This is timepoint 1.
#
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-13
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# /home/basia/.local/lib/python3.10/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
# Proportions:
#
# [0.898235063914004]
#
#
# Proportion_of_noise_in_components:
#
# 0.04240924303500019
#
#
# This is timepoint 2.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8889470754170005]
#
#
# Proportion_of_noise_in_components:
#
# 0.04336129461000002
#
#
# This is timepoint 3.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8837924650080036]
#
#
# Proportion_of_noise_in_components:
#
# 0.04428948398200018
#
#
# This is timepoint 4.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8787698636729977]
#
#
# Proportion_of_noise_in_components:
#
# 0.04494948025199988
#
#
# This is timepoint 5.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8727514584509981]
#
#
# Proportion_of_noise_in_components:
#
# 0.045514643073999904
#
#
# This is timepoint 6.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8668474862840018]
#
#
# Proportion_of_noise_in_components:
#
# 0.04623504847200009
#
#
# This is timepoint 7.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8611221794010011]
#
#
# Proportion_of_noise_in_components:
#
# 0.04706172916400006
#
#
# This is timepoint 8.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8560104440410017]
#
#
# Proportion_of_noise_in_components:
#
# 0.0482730504820001
#
#
# This is timepoint 9.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8516230772989988]
#
#
# Proportion_of_noise_in_components:
#
# 0.04992665578599993
#
#
# This is timepoint 10.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8481728436909993]
#
#
# Proportion_of_noise_in_components:
#
# 0.05238025044799996
#
#
# This is timepoint 11.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8459322536819978]
#
#
# Proportion_of_noise_in_components:
#
# 0.05607341343599985
#
#
# This is timepoint 12.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.846547324079]
#
#
# Proportion_of_noise_in_components:
#
# 0.062544368032
#
#
# This is timepoint 13.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8526379255669987]
#
#
# Proportion_of_noise_in_components:
#
# 0.07423314213499989
#
#
# This is timepoint 14.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8637883939580006]
#
#
# Proportion_of_noise_in_components:
#
# 0.08629000697000005
#
#
# This is timepoint 15.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.874987020052996]
#
#
# Proportion_of_noise_in_components:
#
# 0.09151801956799958
#
#
# This is timepoint 16.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8864445617899978]
#
#
# Proportion_of_noise_in_components:
#
# 0.09356472628299976
#
#
# This is timepoint 17.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.8975130426760007]
#
#
# Proportion_of_noise_in_components:
#
# 0.09487626193000008
#
#
# This is timepoint 18.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9066643943939989]
#
#
# Proportion_of_noise_in_components:
#
# 0.09589988195399989
#
#
# This is timepoint 19.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9147090122680025]
#
#
# Proportion_of_noise_in_components:
#
# 0.09678120470300026
#
#
# This is timepoint 20.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9222272773449989]
#
#
# Proportion_of_noise_in_components:
#
# 0.09759988165099988
#
#
# This is timepoint 21.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9295041842289988]
#
#
# Proportion_of_noise_in_components:
#
# 0.09838924870899987
#
#
# This is timepoint 22.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9367540811419988]
#
#
# Proportion_of_noise_in_components:
#
# 0.09917286365599987
#
#
# This is timepoint 23.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9437602250599999]
#
#
# Proportion_of_noise_in_components:
#
# 0.09993156863599999
#
#
# This is timepoint 24.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9505819832909969]
#
#
# Proportion_of_noise_in_components:
#
# 0.10066965148099968
#
#
# This is timepoint 25.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9568639920450012]
#
#
# Proportion_of_noise_in_components:
#
# 0.10134144471900014
#
#
# This is timepoint 26.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9625159523510014]
#
#
# Proportion_of_noise_in_components:
#
# 0.10195337436500015
#
#
# This is timepoint 27.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9683879653130016]
#
#
# Proportion_of_noise_in_components:
#
# 0.10258672544900017
#
#
# This is timepoint 28.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9738749956850011]
#
#
# Proportion_of_noise_in_components:
#
# 0.10317462690100011
#
#
# This is timepoint 29.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.978582699570002]
#
#
# Proportion_of_noise_in_components:
#
# 0.10367981236800021
#
#
# This is timepoint 30.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9826312197109967]
#
#
# Proportion_of_noise_in_components:
#
# 0.10411709624499964
#
#
# This is timepoint 31.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9861299143919978]
#
#
# Proportion_of_noise_in_components:
#
# 0.10449099277099977
#
#
# This is timepoint 32.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9890189518829974]
#
#
# Proportion_of_noise_in_components:
#
# 0.10479490383799972
#
#
# This is timepoint 33.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9912876294800005]
#
#
# Proportion_of_noise_in_components:
#
# 0.10504377934200004
#
#
# This is timepoint 34.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9932244625409992]
#
#
# Proportion_of_noise_in_components:
#
# 0.1052487620379999
#
#
# This is timepoint 35.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9947702170809993]
#
#
# Proportion_of_noise_in_components:
#
# 0.10541422612999993
#
#
# This is timepoint 36.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9960956799920011]
#
#
# Proportion_of_noise_in_components:
#
# 0.10555814500400011
#
#
# This is timepoint 37.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9971901919249988]
#
#
# Proportion_of_noise_in_components:
#
# 0.10567328246099987
#
#
# This is timepoint 38.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9982748223060008]
#
#
# Proportion_of_noise_in_components:
#
# 0.1057887277790001
#
#
# This is timepoint 39.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9992219605610018]
#
#
# Proportion_of_noise_in_components:
#
# 0.1058941142650002
#
#
# This is timepoint 40.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000022]
#
#
# Proportion_of_noise_in_components:
#
# 0.10581014953900024
#
#
# This is timepoint 41.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9999999999999964]
#
#
# Proportion_of_noise_in_components:
#
# 0.10466515478499963
#
#
# This is timepoint 42.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000004]
#
#
# Proportion_of_noise_in_components:
#
# 0.10367330728800005
#
#
# This is timepoint 43.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000013]
#
#
# Proportion_of_noise_in_components:
#
# 0.10271333349700014
#
#
# This is timepoint 44.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000022]
#
#
# Proportion_of_noise_in_components:
#
# 0.10206445824800023
#
#
# This is timepoint 45.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9999999999999978]
#
#
# Proportion_of_noise_in_components:
#
# 0.10122942656299978
#
#
# This is timepoint 46.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000036]
#
#
# Proportion_of_noise_in_components:
#
# 0.10064474929600035
#
#
# This is timepoint 47.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.999999999999999]
#
#
# Proportion_of_noise_in_components:
#
# 0.10034962948699991
#
#
# This is timepoint 48.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9999999999999997]
#
#
# Proportion_of_noise_in_components:
#
# 0.09995816158499997
#
#
# This is timepoint 49.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000029]
#
#
# Proportion_of_noise_in_components:
#
# 0.09962541178600029
#
#
# This is timepoint 50.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9999999999999982]
#
#
# Proportion_of_noise_in_components:
#
# 0.09940531661499982
#
#
# This is timepoint 51.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0000000000000004]
#
#
# Proportion_of_noise_in_components:
#
# 0.09928180507000005
#
#
# This is timepoint 52.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9999999999999996]
#
#
# Proportion_of_noise_in_components:
#
# 0.09920644544799996
#
#
# This is timepoint 53.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [1.0]
#
#
# Proportion_of_noise_in_components:
#
# 0.098962941413
#
#
# This is timepoint 54.
#
# The mixture's spectrum cannot contain negative intensities.
# Setting negative intensities to zero.
# The mixture's spectrum is not normalized.
# Normalizing mixture's spectrum.
# Proportions:
#
# [0.9999999999999993]
#
#
# Proportion_of_noise_in_components:
#
# 0.09896975749099993

# %%
len(proportions_in_times)
# Out:
# 54

# %%
plt.plot(range(len(proportions_in_times)), [prop[0] for prop in proportions_in_times], 'p')

# %%
with open('../results/PMG_247/comparing_with_first/known_substrats/proportions_in_times_'+str(kappa)+'_'+str(kappa_th)+'.pkl', 'wb') as f:
    pickle.dump(proportions_in_times, f)

# %%
with open('../results/PMG_247/comparing_with_first/known_substrats/noise_proportions_in_times_'+str(kappa)+'_'+str(kappa_th)+'.pkl', 'wb') as f:
    pickle.dump(noise_proportions_in_times, f)

# %% [markdown]
# ### Linear regression

# %%
with open(r'../results/PMG_247/comparing_with_first/known_substrats/proportions_in_times_'+str(kappa)+'_'+str(kappa_th)+'.pkl', 'rb') as f:
    y = pickle.load(f)
    y = np.array(y)

# %%
t = np.array(range(1, y.shape[0]+1))
t_and_ones = np.vstack([t, np.ones(len(t))]).T

# %%
reagent_number = 0

# %%
slope, intercept = np.linalg.lstsq(t_and_ones, y)[0][:,reagent_number]
# Out:
# /tmp/ipykernel_4197/1931212556.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   slope, intercept = np.linalg.lstsq(t_and_ones, y)[0][:,reagent_number]

# %%
plt.plot(range(len(y)), [prop[0] for prop in y], 'p')
plt.plot(slope*t+intercept)
